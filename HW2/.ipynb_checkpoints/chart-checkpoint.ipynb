# %%
# %matplotlib inline
import matplotlib.pyplot as plt
test_cases = ["public1", "public2", "public3", "public4", "public5", "public6"]
aprior_with_time_limit_cutsize = [339, 3118, 70431, 2212, 3719, 332655]
balanceprior_with_time_limit_cutsize = [291, 5835, 57972, 1861, 4639, 323236]
aprior_no_time_limit_cutsize = [339, 3118, 51201, 2212, 3055, 328100]
balanceprior_no_time_limit_cutsize = [291, 5835, 63204, 1861, 2408, 323185]

aprior_with_time_limit_runtime = [0.01, 44.99, 290.81, 2.37, 96.85, 292]
balanceprior_with_time_limit_runtime = [0.01, 61.19, 291.14, 2.05, 85.03, 291.59]
aprior_no_time_limit_runtime = [0.09, 45.30, 290.43, 2.29, 99.75, 291.684]
balanceprior_no_time_limit_runtime = [0.08, 46.73, 290.67, 2.68, 233.06, 291.73]

plt.figure(figsize=(12, 6))

# %%
# for i, test_case in enumerate(test_cases):
#     x = [1, 2, 3, 4]
#     cutsize_data = [
#         aprior_with_time_limit_cutsize[i],
#         balanceprior_with_time_limit_cutsize[i],
#         aprior_no_time_limit_cutsize[i],
#         balanceprior_no_time_limit_cutsize[i],
#     ]
#     plt.hist(x, cutsize_data, width = 0.2, label = test_case)
plt.bar(aprior_with_time_limit_cutsize[0], balanceprior_with_time_limit_cutsize[0])


plt.title("Cutsize Comparison")
plt.xlabel("Test cases")
plt.ylabel("Cutsize")
# plt.legend()

plt.show()
